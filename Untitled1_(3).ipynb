# %% [markdown]
# <a href="https://colab.research.google.com/github/mgonzalez547-design/funpro/blob/main/Untitled1_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1) Verificar si un número es positivo, negativo o cero

# %%
n = float(input("Ingrese un numero: "))

if n > 0:
    print("Positivo")
elif n < 0:
    print("Negativo")
else:
    print("Cero")
# Out:
# Ingrese un numero: -2
# Negativo

# %% [markdown]
# ![18653642-debf-425d-ac00-f7fa202a3acc.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # 2) Determinar si un año es bisiesto

# %% [markdown]
# Un año es bisiesto si es divisible entre 4, excepto si es divisible entre 100, a menos que también sea divisible entre 400. Es decir, un año como 1996 es bisiesto, el 1900 no lo es, pero el año 2000 sí lo es

# %%
año = int(input("Ingrese un año: "))

if año % 4 != 0:
    print(f"{año} no es bisiesto")
elif año % 100 != 0:
    print(f"{año} es bisiesto")
elif año % 400 == 0:
    print(f"{año} es bisiesto")
else:
    print(f"{año} no es bisiesto")
# Out:
# Ingrese un año: 2000
# 2000 es bisiesto

# %% [markdown]
# ![c3a62ebc-7420-421f-8cc1-68be3d780b5c.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 0# 3) Calculadora de Índice de Masa Corporal (IMC)

# %%
peso = float(input("Ingrese su peso en kg: "))
altura = float(input("Ingrese su altura en metros: "))

imc = peso / (altura ** 2)
print(f"IMC: {imc:.2f}")

if imc < 18.5:
    categoria = "Bajo peso"

elif imc < 25.0:
    categoria = "Peso normal"
elif imc < 30.0:
    categoria = "Sobrepeso"
else:
    categoria = "Obesidad"

print("Categoría:", categoria)
# Out:
# Ingrese su peso en kg: 45
# Ingrese su altura en metros: 1.45
# IMC: 21.40
# Categoría: Peso normal

# %% [markdown]
# # 4) Menú de opciones calculadora simple con match/case

# %%
print("Menú de operaciones:")
print("1: Suma")
print("2: Resta")
print("3: Multiplicación")
print("4: División")
opcion = input("Seleccione una opción (1-4): ")

a = float(input("Ingrese el primer número: "))
b = float(input("Ingrese el segundo número: "))

match opcion:
    case "1":
        resultado = a + b
        op = "Suma"
    case "2":
        resultado = a - b
        op = "Resta"
    case "3":
        resultado = a * b
        op = "Multiplicación"
    case "4":
        if b == 0:
          print("Error: división por cero.")
        resultado = a / b
        op = "División"
    case _:
        print("Opción no válida.")

print(f"{op}: {resultado}")
# Out:
# Menú de operaciones:
# 1: Suma
# 2: Resta
# 3: Multiplicación
# 4: División
# Seleccione una opción (1-4): 2
# Ingrese el primer número: 3
# Ingrese el segundo número: 1
# Resta: 2.0

# %% [markdown]
# # 5) Clasificación de triángulos

# %%
a = float(input("Lado a: "))
b = float(input("Lado b: "))
c = float(input("Lado c: "))

if a <= 0 or b <= 0 or c <= 0:
    print("Los lados deben ser positivos.")

# desigualdad triangular
if not (a + b > c and a + c > b and b + c > a):
    print("No forma un triángulo.")

if a == b == c: #primero comprueba este, si no es true pasa a los otros
    print("Triángulo equilátero (todos los lados iguales).")
elif a == b or b == c or a == c:
    print("Triángulo isósceles (dos lados iguales).")
else:
    print("Triángulo escaleno (ningún lado igual).")
# Out:
# Lado a: 3
# Lado b: 4
# Lado c: 3
# Triángulo isósceles (dos lados iguales).
