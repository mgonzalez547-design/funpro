# %% [markdown]
# <a href="https://colab.research.google.com/github/mgonzalez547-design/funpro/blob/main/tarea_sensor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# sensor_detecta = True # True si el sensor funciona, False si no
# humedad = 25 # Valor de humedad del suelo (%)
# prob_lluvia = 30 # Probabilidad de lluvia (%)
# temperatura = 32 # Temperatura en centigrados
# hora_actual = 12 # Hora en 24h

sensor_detecta_input = input("¿El sensor funciona? (True/False): ")
sensor_detecta = sensor_detecta_input.lower() == 'true'

if sensor_detecta :
        humedad = int(input("Introduce el valor de humedad del suelo (%): "))
        prob_lluvia = int(input("Introduce la probabilidad de lluvia (%): "))
        temperatura = int(input("Introduce la temperatura en centígrados: "))
        hora_actual = int(input("Introduce la hora actual (en formato 24h): "))

        if humedad < 35:
            if prob_lluvia < 40:
                if temperatura > 30:
                    if 11 <= hora_actual <= 15:
                        print("No irrigar (horario restringido)")
                    else:
                        print("Irrigar")
                else:
                    print("Irrigar")
            else:
                print("No irrigar (alta probabilidad de lluvia)")
        else:
            print("No irrigar (suelo con suficiente humedad)")
else:
    print("Sensor Error")

# %% [markdown]
# ![Imagen de WhatsApp 2025-09-24 a las 14.17.53_ee58d6dd.jpg](data:image/jpeg;base64,...)

# %%
# kwh = 1200 # consumo en kWh
# estrato = 2 # estrato socioeconómico de 1 a 6
# dia = "domingo" # dia de la semana

kwh = int(input("Introduce el consumo en kWh: "))
estrato = int(input("Introduce el estrato socioeconómico (1 a 6): "))
dia = input("Introduce el día de la semana: ")

if dia.lower() in ["sabado", "domingo", "festivo"]:
    kwh = kwh + 800

precio_base = kwh * 500

if estrato <= 2:
    precio_final = precio_base * 0.8
else:
    precio_final = precio_base

print(f"Consumo: {kwh} kWh")
print(f"Estrato: {estrato}")
print(f"Día: {dia}")
print(f"Precio final: ${precio_final:,.2f}")
# Out:
# Introduce el consumo en kWh: 241234
# Introduce el estrato socioeconómico (1 a 6): 2
# Introduce el día de la semana: domingo
# Consumo: 242034 kWh
# Estrato: 2
# Día: domingo
# Precio final: $96,813,600.00

# %% [markdown]
# ![Imagen de WhatsApp 2025-09-24 a las 14.18.03_98a2250c.jpg](data:image/jpeg;base64,...)
